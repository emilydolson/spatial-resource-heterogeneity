# %%
import os
import numpy, scipy, matplotlib
import matplotlib.pyplot as plt
import csv
import sys
import glob

# %%
path = "/home/emily/repos/resource-heterogeneity/experiment/"
os.chdir(path)
files = glob.glob("*common*")
files.sort()
conditions = ['radius6_distance12_common', 'radius8_distance12_common', 'radius10_distance12_common', 
              'radius15_distance12_common', 'radius20_distance12_common',\
              'inflow100_radius24_commonresources', 'inflow100_radius30_commonresources', 'inflow100_radius36_commonresources', \
              'inflow100_radius48_commonresources', 'inflow100_radius59_commonresources']


def getData(condition):
    diversities = []
    equs = []
    try:
        dirs = os.listdir(condition)
    except:
        return [], []
    for d in dirs:
        diversityfile = open(condition + "/" + d +"/phenotype_count.dat")
        diversities.append(float(diversityfile.readlines()[-1].split()[2]))
        diversityfile.close()
        taskfile = open(condition + "/" + d + "/tasks.dat")
        equs.append(int(taskfile.readlines()[-1].split()[9]))
        taskfile.close()
   
    print len(equs)
    print diversities
    #csv_out3 = open('depletable_inflow100_equs.csv', 'a')
    #mywriter3 = csv.writer(csv_out3)
    
    #for j in range(len(equs2)):
     #   mywriter3.writerow([condition,equs2[j]])
    #csv_out3.close()
    
    #print diversities
    #csv_out4 = open('depletable_inflow100_divs.csv', 'a')
    #mywriter4 = csv.writer(csv_out4)
    
    #for j in range(len(diversities2)):
     #   mywriter4.writerow([condition,diversities2[j]])
    #csv_out4.close()
    
    
    return diversities[0:30], equs[0:30]


def doStats(conditions):
    divs = []
    equs = []
    for c in conditions:
        d, e = getData(c)
        if d == []:
            continue
        divs.append(d)
        e = [int(i>0) for i in e]
        equs.append(e)
    
    plt.figure(1)
    plt.xlabel("Treatment(radius)")
    plt.ylabel("Phenotypic Shannon entropy of viable organisms")
    plt.title("Diversity Distributions over Entropy Treatments")
    plt.boxplot(divs, notch=True)
    equHeights = [sum(i) for i in equs]
    plt.xticks([1, 2, 3, 4, 5, 6, 7, 8, 9], ["0", "2", "3", "5", "6","8","10", "12", "14"], rotation='horizontal')
    
    
    plt.figure(2)
    plt.title("Evolution of EQU over Entropy Treatments")
    plt.xlabel("Treatment (radius)")
    plt.ylabel("# of populations that evolved EQU by 100,000 updates")
    plt.bar(range(len(equHeights)), equHeights)
    plt.xticks([0.4, 1.4, 2.4, 3.4, 4.4, 5.4, 6.4, 7.4, 8.4, 9.4], ["6","8","10","15", "20","24", "30", "36", "48", "59"], rotation='horizontal')
   
    
doStats(conditions)
getData(conditions)
# Out:
# 30
# [0.0, 0.0, 0.0, 0.400684, 0.810159, 0.408636, 0.0, 0.889134, 2.37623, 1.34876, 0.0, 1.06371, 0.0, 1.1531, 0.232673, 0.0, 0.663224, 1.33687, 0.0, 0.854907, 1.00248, 2.28445, 0.849741, 1.32581, 0.0, 0.0, 1.12877, 0.337781, 0.0, 0.22936]
# 30
# [1.84308, 2.93744, 0.46705, 0.0, 3.09883, 3.359, 1.52718, 2.93337, 2.17387, 2.32761, 3.19083, 2.57801, 2.47684, 2.72318, 2.82335, 0.0, 2.48433, 3.19842, 3.24182, 2.53356, 2.98598, 3.55711, 2.82118, 2.02365, 2.96647, 2.11424, 3.06726, 2.78787, 3.7188, 3.16164]
# 30
# [4.50485, 3.98094, 3.84987, 4.01017, 3.96025, 2.39852, 4.06467, 3.78374, 3.4322, 4.20616, 4.26028, 3.67221, 4.1344, 4.03661, 3.72862, 4.23894, 3.94303, 3.90487, 3.58722, 3.40177, 3.3228, 3.7713, 2.90145, 3.77882, 3.93589, 3.92129, 4.21912, 4.0412, 4.04133, 3.82705]
