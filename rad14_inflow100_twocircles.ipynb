# %%
import os
import numpy, scipy, matplotlib
import matplotlib.pyplot as plt
import csv
import sys

# %%
path = "C:\\Users\\Samuel Perez\\Documents\\GitHub\\resource-heterogeneity\\experiment"
#path = Audra's path
#path = Emily's path
os.chdir(path)
conditions = ["15_notXorn","16_notXorn","17_notXorn","18_notXorn","19_notXorn","2circles_notXorn25","2circles_notXorn26","2circles_notXorn27","2circles_notXorn28","2circles_notXorn29"]


def getData(condition):
    diversities = []
    task1 = []
    task2 = []
    try:
        dirs = os.listdir(condition)
    except:
        return [], []
    for d in dirs:
        diversityfile = open(condition + "/" + d +"/phenotype_count.dat")
        diversities.append(float(diversityfile.readlines()[-1].split()[2]))
        diversityfile.close()
        task1file = open(condition + "/" + d + "/tasks.dat")
        task1.append(int(task1file.readlines()[-1].split()[1]))
        task1file.close()
        task2file = open(condition + "/" + d + "/tasks.dat")
        task2.append(int(task2file.readlines()[-1].split()[2]))
        task2file.close()
   
    print task1,task2
    #csv_out3 = open('depletable_inflow100_equs.csv', 'a')
    #mywriter3 = csv.writer(csv_out3)
    
    #for j in range(len(equs2)):
     #   mywriter3.writerow([condition,equs2[j]])
    #csv_out3.close()
    
    #print diversities
    #csv_out4 = open('depletable_inflow100_divs.csv', 'a')
    #mywriter4 = csv.writer(csv_out4)
    
    #for j in range(len(diversities2)):
     #   mywriter4.writerow([condition,diversities2[j]])
    #csv_out4.close()
    
    
    return diversities, task1, task2


def doStats(conditions):
    divs = []
    task1 = []
    task2= []
    for c in conditions:
        d, e, f = getData(c)
        if d == []:
            continue
        divs.append(d)
        e = [int(i>0) for i in e]
        f = [int(i>0) for i in f]
        task1.append(e)
        task1.append(f)
    
    plt.figure(1)
    plt.xlabel("Treatment(radius)")
    plt.ylabel("Phenotypic Shannon entropy of viable organisms")
    plt.title("Diversity Distributions over Entropy Treatments")
    plt.boxplot(divs, notch=True)
    task1Heights = [sum(i) for i in task1]
    plt.xticks([1, 2, 3, 4, 5], ["25", "26", "27", "28", "29"], rotation='horizontal')
    
    
    plt.figure(2)
    plt.title("Evolution of task over Entropy Treatments")
    plt.xlabel("Treatment (radius)")
    plt.ylabel("# of populations that evolved Task1 by 100,000 updates")
    plt.bar(range(len(task1Heights)), task1Heights)
    plt.xticks([0.4, 1.4, 2.4, 3.4, 4.4, 5.4, 6.4, 7.4, 8.4, 9.4], ["25","26","27",'28','29'], rotation='horizontal')
   
    
doStats(conditions)
getData(conditions)
# Out:
# [660, 0, 746, 585, 717, 783, 894, 39, 459, 770, 863, 517, 730, 539, 419, 633, 753, 0, 527, 557, 874, 569, 666, 0, 872, 340, 643, 744, 743, 271] [597, 658, 628, 763, 688, 802, 652, 324, 570, 725, 359, 551, 770, 515, 0, 772, 928, 0, 748, 683, 776, 809, 707, 0, 687, 633, 615, 559, 644, 563]
# [806, 657, 523, 851, 775, 546, 702, 671, 783, 615, 712, 1, 499, 388, 549, 555, 619, 693, 621, 573, 587, 578, 801, 891, 739, 523, 0, 519, 734, 461] [587, 681, 547, 619, 571, 580, 820, 835, 744, 762, 790, 399, 554, 495, 86, 727, 665, 778, 837, 514, 819, 534, 741, 786, 730, 625, 0, 862, 717, 613]
# [769, 1014, 54, 761, 568, 595, 880, 823, 681, 592, 789, 780, 657, 628, 693, 766, 745, 0, 685, 0, 1032, 836, 651, 864, 514, 872, 948, 744, 715, 1224]
#  [743, 818, 598, 666, 645, 700, 614, 744, 842, 897, 765, 747, 638, 673, 683, 837, 806, 0, 555, 0, 648, 790, 725, 934, 642, 735, 612, 669, 887, 677]
# ...

# %%
path2 = "C:\\Users\\Samuel Perez\\Documents\\GitHub\\resource-heterogeneity\\experiment"

path = "C:\\Users\\Samuel Perez\\Documents\\GitHub\\resource-heterogeneity\\experiment"
#path = Audra's path
#path = Emily's path
os.chdir(path2)
conditions = ["2circles_notXorn25","2circles_notXorn26","2circles_notXorn27","2circles_notXorn28","2circles_notXorn29"]


def getData2(condition):
    diversities = []
    task3 = []
    try:
        dirs = os.listdir(condition)
    except:
        return [], []
    for d in dirs:
        task3file = open(condition + "/" + d + "/grid_task.100000.dat")
        for line in task3file.line:
        print line    
        #task1.append(int(task1file.readlines()[-1].split()[1])
        task3file.close()
# Out:
#   File "<ipython-input-12-a83b5c2974da>", line 20
#     print line
#         ^
# IndentationError: expected an indented block

# %%
path2 = "C:\\Users\\Samuel Perez\\Documents\\GitHub\\resource-heterogeneity\\experiment"
os.chdir(path2)
condition = ["2circles_notXorn25","2circles_notXorn26","2circles_notXorn27","2circles_notXorn28","2circles_notXorn29"]

for i in condition:
    diversities = []
    task3 = []
    try:
        dirs = os.listdir(condition)
    #except:
    #    return [], []
    for d in condition:
        task3file = open(condition + "/" + d + "/grid_task.100000.dat")
        for line in task3file:
            print line    
        #task1.append(int(task1file.readlines()[-1].split()[1])
        task3file.close()
# Out:
#   File "<ipython-input-21-59b57b735734>", line 12
#     for d in condition:
#       ^
# SyntaxError: invalid syntax

# %%
path2 = "C:\\Users\\Samuel Perez\\Documents\\GitHub\\resource-heterogeneity\\experiment"
os.chdir(path2)
condition = ["2circles_notXorn25","2circles_notXorn26","2circles_notXorn27","2circles_notXorn28","2circles_notXorn29"]
# Out:
# ['2circles_notXorn25', '2circles_notXorn26', '2circles_notXorn27', '2circles_notXorn28', '2circles_notXorn29']
